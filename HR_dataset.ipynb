# %%
import pandas as pd
import numpy as np
from datetime import date

# %%
df = pd.read_csv("HRDataset_v13.csv")

# %%
df.head()
# Out:
#           Employee_Name       EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0            Brown, Mia  1103024456          1                1         0
# 1  LaRotonda, William    1106026572          0                2         1
# 2      Steans, Tyrone    1302053333          0                0         1
# 3       Howard, Estelle  1211050782          1                1         0
# 4           Singh, Nan   1307059817          0                0         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  PayRate  ...  \
# 0            1       1            3                       1    28.50  ...
# 1            1       1            3                       0    23.00  ...
# 2            1       1            3                       0    29.00  ...
# 3            1       1            3                       0    21.50  ...
# 4            1       1            3                       0    16.56  ...
#
#       Department         ManagerName ManagerID       RecruitmentSource  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 35 columns):
# Employee_Name                 310 non-null object
# EmpID                         310 non-null int64
# MarriedID                     310 non-null int64
# MaritalStatusID               310 non-null int64
# GenderID                      310 non-null int64
# EmpStatusID                   310 non-null int64
# DeptID                        310 non-null int64
# PerfScoreID                   310 non-null int64
# FromDiversityJobFairID        310 non-null int64
# PayRate                       310 non-null float64
# Termd                         310 non-null int64
# PositionID                    310 non-null int64
# Position                      310 non-null object
# State                         310 non-null object
# Zip                           310 non-null int64
# DOB                           310 non-null object
# Sex                           310 non-null object
# ...

# %%
df['DateofTermination']
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3        04/15/15
# 4             NaN
# 5        09/25/13
# 6      08-02-2014
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11     09-05-2015
# 12            NaN
# 13       10/31/14
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# 28            NaN
# 29            NaN
#           ...
# 280      08/30/10
# 281           NaN
# 282      04/24/14
# 283           NaN
# 284           NaN
# 285           NaN
# 286           NaN
# 287           NaN
# 288      08/15/15
# 289           NaN
# 290           NaN
# 291           NaN
# 292    06-05-2013
# 293           NaN
# 294    09-07-2015
# 295           NaN
# 296           NaN
# 297      04/15/14
# 298           NaN
# ...

# %%
df.drop(["Employee_Name","Sex","EmpID","MaritalDesc","ManagerID","DaysLateLast30"],axis=1,inplace=True)

# %%
#df['Zip'].value_counts()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 29 columns):
# MarriedID                     310 non-null int64
# MaritalStatusID               310 non-null int64
# GenderID                      310 non-null int64
# EmpStatusID                   310 non-null int64
# DeptID                        310 non-null int64
# PerfScoreID                   310 non-null int64
# FromDiversityJobFairID        310 non-null int64
# PayRate                       310 non-null float64
# Termd                         310 non-null int64
# PositionID                    310 non-null int64
# Position                      310 non-null object
# State                         310 non-null object
# Zip                           310 non-null int64
# DOB                           310 non-null object
# CitizenDesc                   310 non-null object
# HispanicLatino                310 non-null object
# RaceDesc                      310 non-null object
# ...

# %%
"""df["DateofTermination"]
df["DateofTermination"].fillna(0,inplace=True)
termination = []
for val in df["DateofTermination"]:
    if val != 0:
        termination.append(1)
    else:
        termination.append(0)
df['termination'] = termination


termination = []
for dates in df["DateofTermination"]:
    if dates == np.NaN:
        termination.append(0)
    else:
        termination.append(1)
df['termination'] = termination

df.head()"""
# Out:
# 'df["DateofTermination"]\ndf["DateofTermination"].fillna(0,inplace=True)\ntermination = []\nfor val in df["DateofTermination"]:\n    if val != 0:\n        termination.append(1)\n    else:\n        termination.append(0)\ndf[\'termination\'] = termination\n\n\ntermination = []\nfor dates in df["DateofTermination"]:\n    if dates == np.NaN:\n        termination.append(0)\n    else:\n        termination.append(1)\ndf[\'termination\'] = termination\n\ndf.head()'

# %%
#df["DateofTermination"]

# %%
#df['termination']

# %%
df['DateofTermination'] = df['DateofTermination'].astype(str)
df['DateofTermination']= pd.to_datetime(df['DateofTermination'])

df['DateofHire'] = df['DateofHire'].astype(str)
df['DateofHire']= pd.to_datetime(df['DateofHire'])


df['daysofwork']=df['DateofTermination']-df['DateofHire']


df["daysofwork"].fillna(0,inplace=True)
# Out:
# C:\Users\prane\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Passing integers to fillna is deprecated, will raise a TypeError in a future version.  To retain the old behavior, pass pd.Timedelta(seconds=n) instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 30 columns):
# MarriedID                     310 non-null int64
# MaritalStatusID               310 non-null int64
# GenderID                      310 non-null int64
# EmpStatusID                   310 non-null int64
# DeptID                        310 non-null int64
# PerfScoreID                   310 non-null int64
# FromDiversityJobFairID        310 non-null int64
# PayRate                       310 non-null float64
# Termd                         310 non-null int64
# PositionID                    310 non-null int64
# Position                      310 non-null object
# State                         310 non-null object
# Zip                           310 non-null int64
# DOB                           310 non-null object
# CitizenDesc                   310 non-null object
# HispanicLatino                310 non-null object
# RaceDesc                      310 non-null object
# ...

# %%
df.head()
# Out:
#    MarriedID  MaritalStatusID  GenderID  EmpStatusID  DeptID  PerfScoreID  \
# 0          1                1         0            1       1            3
# 1          0                2         1            1       1            3
# 2          0                0         1            1       1            3
# 3          1                1         0            1       1            3
# 4          0                0         0            1       1            3
#
#    FromDiversityJobFairID  PayRate  Termd  PositionID  ...  \
# 0                       1    28.50      0           1  ...
# 1                       0    23.00      0           1  ...
# 2                       0    29.00      0           1  ...
# 3                       0    21.50      1           2  ...
# 4                       0    16.56      0           2  ...
#
#        EmploymentStatus     Department         ManagerName  \
# 0                Active  Admin Offices  Brandon R. LeBlanc
# ...

# %%
new_list= []
for y in df["daysofwork"]:
    a=str(y)
    b=a.strip("days")
    print(y.split("days"))
    new_list.append(float(b))
df['days'] = new_list
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-dbc54d4c92ab> in <module>
#       3     a=str(y)
#       4     b=a.strip("days")
# ----> 5     print(y.split("days"))
#       6     new_list.append(float(b))
#       7 df['days'] = new_list
#
# AttributeError: 'Timedelta' object has no attribute 'split'

# %%
daysofwork1 = []
for val in df['daysofwork']:
    for val1 in df['DateofHire']:
        if "0 days" in val:
            #print("yes")
            daysofwork1.append(val1-date.today())
        else:
            daysofwork1.append(val)

# %%
daysofwork1
