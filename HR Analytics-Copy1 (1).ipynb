# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\sunita.chalwadi\Desktop\general_data.csv")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 24 columns):
# Age                        4410 non-null int64
# Attrition                  4410 non-null object
# BusinessTravel             4410 non-null object
# Department                 4410 non-null object
# DistanceFromHome           4410 non-null int64
# Education                  4410 non-null int64
# EducationField             4410 non-null object
# EmployeeCount              4410 non-null int64
# EmployeeID                 4410 non-null int64
# Gender                     4410 non-null object
# JobLevel                   4410 non-null int64
# JobRole                    4410 non-null object
# MaritalStatus              4410 non-null object
# MonthlyIncome              4410 non-null int64
# NumCompaniesWorked         4391 non-null float64
# Over18                     4410 non-null object
# PercentSalaryHike          4410 non-null int64
# ...

# %%
df["NumCompaniesWorked"].unique()
# Out:
# array([ 1.,  0.,  3.,  4.,  2.,  7.,  9.,  5.,  6.,  8., nan])

# %%
df["TotalWorkingYears"].unique()
# Out:
# array([ 1.,  6.,  5., 13.,  9., 28., 10., 21., 16., 37.,  7.,  3., 15.,
#         8., nan, 12., 17., 19., 22.,  2.,  4., 23.,  0., 11., 24., 25.,
#        20., 14., 26., 18., 30., 36., 31., 33., 32., 34., 40., 29., 35.,
#        27., 38.])

# %%
df["Attrition"].value_counts()
# Out:
# No     3699
# Yes     711
# Name: Attrition, dtype: int64

# %%
df_0 = df[df['Attrition']=='Yes']
df_1 = df[df['Attrition']=='No'].sample(n=711, random_state=2)
df_new = pd.concat([df_1, df_0])

# %%
df_new["Attrition"].value_counts()
# Out:
# No     711
# Yes    711
# Name: Attrition, dtype: int64

# %%
df_new["NumCompaniesWorked"]=df_new["NumCompaniesWorked"].fillna(df_new["NumCompaniesWorked"].max())

# %%
df_new["NumCompaniesWorked"].unique()
# Out:
# array([1., 8., 4., 2., 3., 5., 7., 6., 9., 0.])

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2055 to 4402
# Data columns (total 24 columns):
# Age                        1422 non-null int64
# Attrition                  1422 non-null object
# BusinessTravel             1422 non-null object
# Department                 1422 non-null object
# DistanceFromHome           1422 non-null int64
# Education                  1422 non-null int64
# EducationField             1422 non-null object
# EmployeeCount              1422 non-null int64
# EmployeeID                 1422 non-null int64
# Gender                     1422 non-null object
# JobLevel                   1422 non-null int64
# JobRole                    1422 non-null object
# MaritalStatus              1422 non-null object
# MonthlyIncome              1422 non-null int64
# NumCompaniesWorked         1422 non-null float64
# Over18                     1422 non-null object
# PercentSalaryHike          1422 non-null int64
# ...

# %%
totalWorkingYears_mean = df_new['TotalWorkingYears'].mean()
df_new["TotalWorkingYears"].fillna(df_new["TotalWorkingYears"].mean(),inplace=True)

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2055 to 4402
# Data columns (total 24 columns):
# Age                        1422 non-null int64
# Attrition                  1422 non-null object
# BusinessTravel             1422 non-null object
# Department                 1422 non-null object
# DistanceFromHome           1422 non-null int64
# Education                  1422 non-null int64
# EducationField             1422 non-null object
# EmployeeCount              1422 non-null int64
# EmployeeID                 1422 non-null int64
# Gender                     1422 non-null object
# JobLevel                   1422 non-null int64
# JobRole                    1422 non-null object
# MaritalStatus              1422 non-null object
# MonthlyIncome              1422 non-null int64
# NumCompaniesWorked         1422 non-null float64
# Over18                     1422 non-null object
# PercentSalaryHike          1422 non-null int64
# ...

# %%
df_new.head()
# Out:
#       Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 2055   26        No  Travel_Rarely  Research & Development                 1
# 117    49        No  Travel_Rarely                   Sales                 2
# 119    36        No  Travel_Rarely                   Sales                15
# 1883   34        No  Travel_Rarely  Research & Development                12
# 2570   31        No  Travel_Rarely                   Sales                 9
#
#       Education    EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 2055          4     Life Sciences              1        2056    Male  ...
# 117           3  Technical Degree              1         118    Male  ...
# 119           2     Life Sciences              1         120    Male  ...
# 1883          2  Technical Degree              1        1884    Male  ...
# 2570          4     Life Sciences              1        2571  Female  ...
#
# ...

# %%
df_new_cat = df_new.select_dtypes(object)
df_new_num = df_new.select_dtypes(["float64","int64"])

# %%
df_new_cat.head()
# Out:
#      Attrition BusinessTravel              Department    EducationField  \
# 2055        No  Travel_Rarely  Research & Development     Life Sciences
# 117         No  Travel_Rarely                   Sales  Technical Degree
# 119         No  Travel_Rarely                   Sales     Life Sciences
# 1883        No  Travel_Rarely  Research & Development  Technical Degree
# 2570        No  Travel_Rarely                   Sales     Life Sciences
#
#       Gender                 JobRole MaritalStatus Over18
# 2055    Male    Sales Representative       Married      Y
# 117     Male  Manufacturing Director        Single      Y
# 119     Male         Sales Executive       Married      Y
# 1883    Male         Human Resources      Divorced      Y
# 2570  Female         Sales Executive      Divorced      Y

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for col in df_new_cat:
    le = LabelEncoder()
    df_new_cat[col] = le.fit_transform(df_new_cat[col])
# Out:
# C:\Users\sunita.chalwadi\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df1=pd.concat([df_new_num,df_new_cat],axis=1)

# %%
df1.head()
# Out:
#       Age  DistanceFromHome  Education  EmployeeCount  EmployeeID  JobLevel  \
# 2055   26                 1          4              1        2056         2
# 117    49                 2          3              1         118         2
# 119    36                15          2              1         120         1
# 1883   34                12          2              1        1884         2
# 2570   31                 9          4              1        2571         1
#
#       MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  StandardHours  \
# 2055         143360                 1.0                 21              8
# 117           52040                 8.0                 14              8
# 119           96790                 4.0                 12              8
# 1883          88650                 1.0                 11              8
# 2570         161240                 2.0                 23              8
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
for col in df1:
    mx = MinMaxScaler()
    df1[col] = mx.fit_transform(df1[[col]])
df1.head()
# Out:
#            Age  DistanceFromHome  Education  EmployeeCount  EmployeeID  \
# 2055  0.190476          0.000000       0.75            0.0    0.466712
# 117   0.738095          0.035714       0.50            0.0    0.026358
# 119   0.428571          0.500000       0.25            0.0    0.026812
# 1883  0.380952          0.392857       0.25            0.0    0.427630
# 2570  0.309524          0.285714       0.75            0.0    0.583731
#
#       JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# 2055      0.25       0.702753            0.111111           0.714286
# 117       0.25       0.221209            0.888889           0.214286
# 119       0.00       0.457182            0.444444           0.071429
# 1883      0.25       0.414259            0.111111           0.000000
# 2570      0.00       0.797036            0.222222           0.857143
#
#       StandardHours  ...  YearsSinceLastPromotion  YearsWithCurrManager  \
# ...

# %%
df1.drop(['EmployeeID'], axis = 1)
# Out:
#            Age  DistanceFromHome  Education  EmployeeCount  JobLevel  \
# 2055  0.190476          0.000000       0.75            0.0      0.25
# 117   0.738095          0.035714       0.50            0.0      0.25
# 119   0.428571          0.500000       0.25            0.0      0.00
# 1883  0.380952          0.392857       0.25            0.0      0.25
# 2570  0.309524          0.285714       0.75            0.0      0.00
# ...        ...               ...        ...            ...       ...
# 4381  0.261905          0.214286       0.00            0.0      0.00
# 4386  0.357143          0.357143       0.75            0.0      0.00
# 4388  0.357143          0.000000       0.50            0.0      0.25
# 4391  0.333333          0.785714       0.00            0.0      0.50
# 4402  0.452381          0.035714       0.50            0.0      0.00
#
#       MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  StandardHours  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x = df1.drop('Attrition',axis=1)
y = df1['Attrition']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,
                                                 random_state=1)

# %%
print(y_test.unique())
# Out:
# [1. 0.]

# %%
print(y_train.unique())
# Out:
# [0. 1.]

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
log.fit(x_train,y_train)
log.score(x_test,y_test)
# Out:
# 0.6088992974238876

# %%
from sklearn.metrics import classification_report, confusion_matrix
tn, fp, fn, tp = confusion_matrix(y_test,y_pred).ravel()

print(tp, fn)
print(fp, tn)
# Out:
# 108 110
# 101 108

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.5058548009367682

# %%
from sklearn.ensemble import RandomForestClassifier

x_train, x_test, y_train, y_test = train_test_split(df1, y, test_size=0.3)
#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(x_train,y_train)

y_pred=clf.predict(x_test)

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
dt = DecisionTreeClassifier()

# %%
dt.fit(x_train, y_train)
dt.score(x_test, y_test)
# Out:
# 1.0

# %%
tree.plot_tree(dt.fit(x_train, y_train))
# Out:
# [Text(167.4, 163.07999999999998, 'X[16] <= 0.5\ngini = 0.5\nsamples = 995\nvalue = [501, 494]'),
#  Text(83.7, 54.360000000000014, 'gini = 0.0\nsamples = 501\nvalue = [501, 0]'),
#  Text(251.10000000000002, 54.360000000000014, 'gini = 0.0\nsamples = 494\nvalue = [0, 494]')]
